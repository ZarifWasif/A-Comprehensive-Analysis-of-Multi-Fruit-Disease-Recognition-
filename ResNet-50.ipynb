# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 21743 files belonging to 17 classes.
# 2025-04-09 12:24:15.764953: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2025-04-09 12:24:15.764981: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-04-09 12:24:15.764984: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2025-04-09 12:24:15.765002: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-09 12:24:15.765013: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 5437 files belonging to 17 classes.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (224, 224, 3)

# Load the ResNet50 model with ImageNet weights, excluding the top layers
resnet_base = tf.keras.applications.ResNet50(
    include_top=False,  # Exclude the fully connected layer at the top
    weights='imagenet',  # Use ImageNet weights
    input_shape=input_shape,  # Ensure input shape is set
    pooling='avg'  # Optionally use global average pooling instead of flattening
)

# Freeze the base model (do not train these layers)
resnet_base.trainable = False

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add the ResNet base model
cnn.add(resnet_base)

# Add fully connected layers after the ResNet base
cnn.add(tf.keras.layers.Flatten())  # Flatten the 3D output to 1D for dense layers

# Output layer for 15 classes (adjust based on your dataset)
cnn.add(tf.keras.layers.Dense(units=17, activation='softmax'))

# Compile the model
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary to check layers and parameters
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=50)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('ResNet50_Rice_and_Jack_Fruit_Plant_Disease_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(224, 224),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 2048)           │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 17)             │        34,833 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,622,545 (90.11 MB)
#  Trainable params: 34,833 (136.07 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/50
# 2025-04-09 12:24:26.507028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-04-09 12:24:26.508164: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.4045 - loss: 2.6058 - val_accuracy: 0.7879 - val_loss: 0.5990
# Epoch 2/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.8299 - loss: 0.5078 - val_accuracy: 0.8713 - val_loss: 0.3854
# Epoch 3/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 49ms/step - accuracy: 0.8919 - loss: 0.3329 - val_accuracy: 0.9029 - val_loss: 0.2951
# Epoch 4/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.
50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9989 - loss: 0.0109 - val_accuracy: 0.9807 - val_loss: 0.0536
# Epoch 34/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9991 - loss: 0.0102 - val_accuracy: 0.9825 - val_loss: 0.0520
# Epoch 35/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9990 - loss: 0.0095 - val_accuracy: 0.9827 - val_loss: 0.0526
# Epoch 36/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 35s 51ms/step - accuracy: 0.9990 - loss: 0.0088 - val_accuracy: 0.9816 - val_loss: 0.0525
# Epoch 37/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9991 - loss: 0.0084 - val_accuracy: 0.9820 - val_loss: 0.0521
# Epoch 38/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9991 - loss: 0.0077 - val_accuracy: 0.9820 - val_loss: 0.0525
# Epoch 39/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 35s 51ms/step - accuracy: 0.9991 - loss: 0.0076 - val_accuracy: 0.9818 - val_loss: 0.0530
# Epoch 40/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9991 - loss: 0.0071 - val_accuracy: 0.9822 - val_loss: 0.0539
# Epoch 41/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9993 - loss: 0.0066 - val_accuracy: 0.9827 - val_loss: 0.0528
# Epoch 42/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9993 - loss: 0.0065 - val_accuracy: 0.9838 - val_loss: 0.0529
# Epoch 43/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 35s 51ms/step - accuracy: 0.9992 - loss: 0.0061 - val_accuracy: 0.9825 - val_loss: 0.0548
# Epoch 44/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9993 - loss: 0.0057 - val_accuracy: 0.9829 - val_loss: 0.0545
# Epoch 45/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9995 - loss: 0.0054 - val_accuracy: 0.9823 - val_loss: 0.0541
# Epoch 46/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9994 - loss: 0.0052 - val_accuracy: 0.9831 - val_loss: 0.0543
# Epoch 47/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9993 - loss: 0.0047 - val_accuracy: 0.9825 - val_loss: 0.0545
# Epoch 48/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9993 - loss: 0.0046 - val_accuracy: 0.9833 - val_loss: 0.0541
# Epoch 49/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9993 - loss: 0.0046 - val_accuracy: 0.9820 - val_loss: 0.0556
# Epoch 50/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 34s 50ms/step - accuracy: 0.9996 - loss: 0.0041 - val_accuracy: 0.9836 - val_loss: 0.0555
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 28s 41ms/step - accuracy: 0.9992 - loss: 0.0041
# Training accuracy: 0.999264121055603
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.9842 - loss: 0.0532
# Validation accuracy: 0.9836306571960449
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 5437 files belonging to 17 classes.
# 2025-04-09 12:53:37.984868: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 5437/5437 ━━━━━━━━━━━━━━━━━━━━ 128s 23ms/step
# 2025-04-09 12:55:47.326221: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# True categories:
# [ 0  0  0 ... 16 16 16]
# Predicted categories:
# [ 0  0  1 ... 16 16 16]
#                                precision    recall  f1-score   support
#
#            Citrus__Black Spot       0.99      0.96      0.97       320
#                Citrus__Canker       0.96      0.99      0.98       320
#               Citrus__Healthy       1.00      1.00      1.00       320
#                Guava__Healthy       1.00      1.00      1.00       320
#            Guava__Phytopthora       0.97      0.97      0.97       320
#                   Guava__Scab       0.99      0.99      0.99       320
#        Guava__Styler_and_Root       0.97      0.97      0.97       320
#             Mango__Alternaria       0.99      1.00      1.00       320
#            Mango__Anthracnose       1.00      0.99      1.00       317
#        Mango__Black Mould Rot       1.00      1.00      1.00       320
#                Mango__Healthy       1.00      1.00      1.00       320
#           Mango__Stem end Rot       1.00      1.00      1.00       320
#       Pomegranate__Alternaria       0.97      0.94      0.96       320
#      Pomegranate__Anthracnose       0.97      0.97      0.97       320
# Pomegranate__Bacterial_Blight       0.94      0.97      0.96       320
#       Pomegranate__Cercospora       0.97      0.97      0.97       320
#          Pomegranate__Healthy       0.98      0.99      0.99       320
#
#                      accuracy                           0.98      5437
#                     macro avg       0.98      0.98      0.98      5437
#                  weighted avg       0.98      0.98      0.98      5437

# %%
# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('ResNet-50 Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
#                                precision    recall  f1-score   support
#
#            Citrus__Black Spot       0.99      0.96      0.97       320
#                Citrus__Canker       0.96      0.99      0.98       320
#               Citrus__Healthy       1.00      1.00      1.00       320
#                Guava__Healthy       1.00      1.00      1.00       320
#            Guava__Phytopthora       0.97      0.97      0.97       320
#                   Guava__Scab       0.99      0.99      0.99       320
#        Guava__Styler_and_Root       0.97      0.97      0.97       320
#             Mango__Alternaria       0.99      1.00      1.00       320
#            Mango__Anthracnose       1.00      0.99      1.00       317
#        Mango__Black Mould Rot       1.00      1.00      1.00       320
#                Mango__Healthy       1.00      1.00      1.00       320
#           Mango__Stem end Rot       1.00      1.00      1.00       320
#       Pomegranate__Alternaria       0.97      0.94      0.96       320
#      Pomegranate__Anthracnose       0.97      0.97      0.97       320
# Pomegranate__Bacterial_Blight       0.94      0.97      0.96       320
#       Pomegranate__Cercospora       0.97      0.97      0.97       320
#          Pomegranate__Healthy       0.98      0.99      0.99       320
#
#                      accuracy                           0.98      5437
#                     macro avg       0.98      0.98      0.98      5437
#                  weighted avg       0.98      0.98      0.98      5437

# %%
# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('ResNet-50 Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('ResNet-50 Model Loss')
plt.legend()

plt.show()
