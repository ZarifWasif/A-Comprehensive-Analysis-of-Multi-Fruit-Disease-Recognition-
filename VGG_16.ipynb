# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 21743 files belonging to 17 classes.
# 2025-04-09 13:31:17.204678: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Max
# 2025-04-09 13:31:17.204722: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2025-04-09 13:31:17.204726: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2025-04-09 13:31:17.204756: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-09 13:31:17.204781: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 5437 files belonging to 17 classes.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import json

# Define the input shape for 64x64 image size
input_shape = (224, 224, 3)

# Load the VGG16 model with ImageNet weights, excluding the top layers
vgg_base = tf.keras.applications.VGG16(
    include_top=False,  # Exclude the fully connected layer at the top
    weights='imagenet',  # Use ImageNet weights
    input_shape=input_shape,  # Ensure input shape is set
    pooling='avg'  # Optionally use global average pooling instead of flattening
)

# Freeze the base model (do not train these layers)
vgg_base.trainable = False

# Create a Sequential model
cnn = tf.keras.models.Sequential()

# Add the VGG16 base model
cnn.add(vgg_base)

# Add fully connected layers after the VGG16 base
cnn.add(tf.keras.layers.Flatten())  # Flatten the 3D output to 1D for dense layers

# Output layer for 17 classes (adjust based on your dataset)
cnn.add(tf.keras.layers.Dense(units=17, activation='softmax'))

# Compile the model
cnn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# Display model summary to check layers and parameters
cnn.summary()

# Training the model
training_history = cnn.fit(x=training_set, validation_data=validation_set, epochs=50)

# Training set accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)

# Validation set accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)

# Save the trained model
cnn.save('VGG16_Rice_and_Jack_Fruit_Plant_Disease_Detection_model.keras')

# Save training history as JSON
with open('training_hist.json', 'w') as f:
    json.dump(training_history.history, f)

# Print keys of the training history dictionary
print(training_history.history.keys())

# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('Model Loss')
plt.legend()

plt.show()

# Load validation set class names
class_name = validation_set.class_names

# Load test dataset
test_set = tf.keras.utils.image_dataset_from_directory(
    'test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(224, 224),  # Adjusted to match the input shape
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)

# Predict classes on test set
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1).numpy()

true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1).numpy()

# Display true and predicted categories
print('True categories:')
print(Y_true)
print('Predicted categories:')
print(predicted_categories)

# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 17)             │         8,721 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,723,409 (56.17 MB)
#  Trainable params: 8,721 (34.07 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/50
# 2025-04-09 13:31:23.059680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-04-09 13:31:23.060751: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.1421 - loss: 20.4658 - val_accuracy: 0.4486 - val_loss: 5.7609
# Epoch 2/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.5042 - loss: 4.9071 - val_accuracy: 0.6325 - val_loss: 2.9683
# Epoch 3/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.6538 - loss: 2.7564 - val_accuracy: 0.7076 - val_loss: 2.0569
# Epoch 4/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.7280 - loss: 1.9217 - val_accuracy: 0.7572 - val_loss: 1.5638
# Epoch 5/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.7732 - loss: 1.4485 - val_accuracy: 0.7931 - val_loss: 1.2348
# Epoch 6/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.8075 - loss: 1.1207 - val_accuracy: 0.8185 - val_loss: 1.0062
# Epoch 7/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.8318 - loss: 0.8936 - val_accuracy: 0.8380 - val_loss: 0.8507
# Epoch 8/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.8527 - loss: 0.7391 - val_accuracy: 0.8613 - val_loss: 0.7338
# Epoch 9/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.8688 - loss: 0.5946 - val_accuracy: 0.8700 - val_loss: 0.6460
# Epoch 10/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.8842 - loss: 0.4947 - val_accuracy: 0.8808 - val_loss: 0.5736
# Epoch 11/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.8984 - loss: 0.4217 - val_accuracy: 0.8873 - val_loss: 0.5080
# Epoch 12/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9101 - loss: 0.3560 - val_accuracy: 0.8959 - val_loss: 0.4552
# Epoch 13/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9215 - loss: 0.3091 - val_accuracy: 0.9110 - val_loss: 0.4089
# Epoch 14/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9299 - loss: 0.2707 - val_accuracy: 0.9147 - val_loss: 0.3754
# Epoch 15/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9372 - loss: 0.2404 - val_accuracy: 0.9211 - val_loss: 0.3475
# Epoch 16/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.
50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9861 - loss: 0.0430 - val_accuracy: 0.9630 - val_loss: 0.1577
# Epoch 49/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9876 - loss: 0.0421 - val_accuracy: 0.9651 - val_loss: 0.1522
# Epoch 50/50
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.9880 - loss: 0.0406 - val_accuracy: 0.9656 - val_loss: 0.1539
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - accuracy: 0.9886 - loss: 0.0394
# Training accuracy: 0.9883641004562378
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9625 - loss: 0.1637
# Validation accuracy: 0.9656060338020325
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])
# Found 5437 files belonging to 17 classes.
#   10/5437 ━━━━━━━━━━━━━━━━━━━━ 30s 6ms/step
# 2025-04-09 13:51:04.365831: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 5437/5437 ━━━━━━━━━━━━━━━━━━━━ 35s 6ms/step
# 2025-04-09 13:51:41.612798: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# True categories:
# [ 0  0  0 ... 16 16 16]
# Predicted categories:
# [ 1  0  0 ... 16 16 16]
#                                precision    recall  f1-score   support
#
#            Citrus__Black Spot       0.87      0.94      0.91       320
#                Citrus__Canker       0.94      0.86      0.90       320
#               Citrus__Healthy       1.00      1.00      1.00       320
#                Guava__Healthy       1.00      1.00      1.00       320
#            Guava__Phytopthora       0.96      0.94      0.95       320
#                   Guava__Scab       0.99      0.98      0.98       320
#        Guava__Styler_and_Root       0.95      0.96      0.95       320
#             Mango__Alternaria       0.99      1.00      0.99       320
#            Mango__Anthracnose       0.99      1.00      1.00       317
#        Mango__Black Mould Rot       1.00      1.00      1.00       320
#                Mango__Healthy       1.00      1.00      1.00       320
#           Mango__Stem end Rot       0.99      1.00      1.00       320
#       Pomegranate__Alternaria       0.93      0.94      0.94       320
#      Pomegranate__Anthracnose       0.94      0.95      0.94       320
# Pomegranate__Bacterial_Blight       0.95      0.89      0.92       320
#       Pomegranate__Cercospora       0.95      0.98      0.96       320
#          Pomegranate__Healthy       0.98      0.98      0.98       320
#
#                      accuracy                           0.97      5437
#                     macro avg       0.97      0.97      0.97      5437
#                  weighted avg       0.97      0.97      0.97      5437

# %%
# Generate confusion matrix
cm = confusion_matrix(Y_true, predicted_categories)

# Print precision, recall, f1-score
print(classification_report(Y_true, predicted_categories, target_names=class_name))

plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_name, yticklabels=class_name)

plt.xlabel('Predicted Class', fontsize=12)
plt.ylabel('Actual Class', fontsize=12)
plt.title('VGG-16 Confusion Matrix', fontsize=15)

# Save confusion matrix plot as PNG file
conf_matrix_plot_path = "./image/confusion_matrix_plot.png"
plt.savefig(conf_matrix_plot_path, dpi=300, bbox_inches='tight')

plt.show()
# Out:
#                                precision    recall  f1-score   support
#
#            Citrus__Black Spot       0.87      0.94      0.91       320
#                Citrus__Canker       0.94      0.86      0.90       320
#               Citrus__Healthy       1.00      1.00      1.00       320
#                Guava__Healthy       1.00      1.00      1.00       320
#            Guava__Phytopthora       0.96      0.94      0.95       320
#                   Guava__Scab       0.99      0.98      0.98       320
#        Guava__Styler_and_Root       0.95      0.96      0.95       320
#             Mango__Alternaria       0.99      1.00      0.99       320
#            Mango__Anthracnose       0.99      1.00      1.00       317
#        Mango__Black Mould Rot       1.00      1.00      1.00       320
#                Mango__Healthy       1.00      1.00      1.00       320
#           Mango__Stem end Rot       0.99      1.00      1.00       320
#       Pomegranate__Alternaria       0.93      0.94      0.94       320
#      Pomegranate__Anthracnose       0.94      0.95      0.94       320
# Pomegranate__Bacterial_Blight       0.95      0.89      0.92       320
#       Pomegranate__Cercospora       0.95      0.98      0.96       320
#          Pomegranate__Healthy       0.98      0.98      0.98       320
#
#                      accuracy                           0.97      5437
#                     macro avg       0.97      0.97      0.97      5437
#                  weighted avg       0.97      0.97      0.97      5437

# %%
# Plot training and validation accuracy
epochs = range(1, len(training_history.history['accuracy']) + 1)
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, training_history.history['accuracy'], color='blue', label='Training Accuracy')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('VGG-16 Model Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, training_history.history['loss'], color='blue', label='Training Loss')
plt.plot(epochs, training_history.history['val_loss'], color='orange', label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.title('VGG-16 Model Loss')
plt.legend()

plt.show()
